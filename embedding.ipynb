# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
### sentences
sent=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## Define vocabulary size
voc_size = 10000

# %%
### One hot representation
one_hot_rep=[one_hot(words, voc_size) for words in sent]
one_hot_rep
# Out:
# [[8876, 3068, 9809, 4634],
#  [8876, 3068, 9809, 9317],
#  [8876, 9106, 9809, 246],
#  [4396, 5625, 6279, 7887, 7256],
#  [4396, 5625, 6279, 7887, 1044],
#  [8167, 8876, 5774, 9809, 1703],
#  [3403, 6779, 5471, 7887]]

# %%
## Word embedding repesentation
from tensorflow.keras.layers import Embedding 
# from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=8
embedded_docs=pad_sequences(one_hot_rep, padding='pre', maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 8876 3068 9809 4634]
#  [   0    0    0    0 8876 3068 9809 9317]
#  [   0    0    0    0 8876 9106 9809  246]
#  [   0    0    0 4396 5625 6279 7887 7256]
#  [   0    0    0 4396 5625 6279 7887 1044]
#  [   0    0    0 8167 8876 5774 9809 1703]
#  [   0    0    0    0 3403 6779 5471 7887]]

# %%
##feature representation
dim=10

# %%
## Create model
model = Sequential()
model.add(Embedding(voc_size, dim, input_length=sent_length))
model.compile('adam','mse')
# Out:
# 2025-07-11 06:12:27.808335: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Pro
# 2025-07-11 06:12:27.808484: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 18.00 GB
# 2025-07-11 06:12:27.808493: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 6.00 GB
# 2025-07-11 06:12:27.808708: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-07-11 06:12:27.809050: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 195ms/step
# 2025-07-11 06:15:27.778340: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# array([[[ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [ 0.04895855, -0.04695929, -0.02911696,  0.02520982,
#          -0.02439896,  0.01605536, -0.03923155,  0.01901117,
#          -0.0134467 , -0.01331465],
#         [ 0.03579423, -0.01314446,  0.01488168, -0.0026217 ,
#           0.03737228,  0.02327147,  0.0026065 , -0.01311885,
#           0.03220752, -0.04723945],
#         [ 0.01653901, -0.0246666 ,  0.03465729,  0.02819493,
#           0.0063339 ,  0.0120704 ,  0.00223341,  0.00457009,
#           0.02366206,  0.0341008 ],
#         [-0.03756753, -0.04819441,  0.00537108,  0.0051433 ,
#           0.02728419,  0.02219539, -0.01196307, -0.0172388 ,
#           0.01043321, -0.04930372]],
#
#        [[ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [ 0.04895855, -0.04695929, -0.02911696,  0.02520982,
#          -0.02439896,  0.01605536, -0.03923155,  0.01901117,
#          -0.0134467 , -0.01331465],
#         [ 0.03579423, -0.01314446,  0.01488168, -0.0026217 ,
#           0.03737228,  0.02327147,  0.0026065 , -0.01311885,
#           0.03220752, -0.04723945],
#         [ 0.01653901, -0.0246666 ,  0.03465729,  0.02819493,
#           0.0063339 ,  0.0120704 ,  0.00223341,  0.00457009,
#           0.02366206,  0.0341008 ],
#         [-0.03572384,  0.00045024, -0.02651206,  0.03642322,
#           0.01676372, -0.03076007, -0.02672516, -0.04398562,
#          -0.02918223,  0.00347804]],
#
#        [[ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [ 0.04895855, -0.04695929, -0.02911696,  0.02520982,
#          -0.02439896,  0.01605536, -0.03923155,  0.01901117,
#          -0.0134467 , -0.01331465],
#         [ 0.03290843,  0.04310724,  0.01866524,  0.04541743,
#           0.02845183,  0.0433499 , -0.04461951, -0.02989185,
#          -0.02895887, -0.03819286],
#         [ 0.01653901, -0.0246666 ,  0.03465729,  0.02819493,
#           0.0063339 ,  0.0120704 ,  0.00223341,  0.00457009,
#           0.02366206,  0.0341008 ],
#         [ 0.03016791,  0.04216911, -0.03167641, -0.00640924,
#          -0.04940135, -0.0024256 , -0.01537479,  0.04002284,
#           0.03941179, -0.01402185]],
#
#        [[ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [-0.00640433,  0.01230996,  0.004714  , -0.03911813,
#          -0.00942696,  0.00595114,  0.04307251,  0.03237944,
#           0.0156565 ,  0.01494961],
#         [-0.0024165 ,  0.04842528, -0.02754558,  0.02155757,
#          -0.02986733, -0.01618611, -0.04429476,  0.0204294 ,
#          -0.03991799,  0.03240738],
#         [ 0.02901992, -0.00490061, -0.01441953, -0.03024347,
#           0.00707173,  0.01166882,  0.04656357, -0.04787156,
#          -0.03581198, -0.01590328],
#         [ 0.00111089, -0.02144997, -0.04005747, -0.0203434 ,
#           0.03359219,  0.04789321,  0.04347836,  0.03340851,
#          -0.02520965, -0.01633744],
#         [-0.03610995, -0.03978548, -0.00677438, -0.01888952,
#          -0.03971844,  0.03154152, -0.00390539, -0.00884328,
#          -0.01049217, -0.03932208]],
#
#        [[ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [-0.00640433,  0.01230996,  0.004714  , -0.03911813,
#          -0.00942696,  0.00595114,  0.04307251,  0.03237944,
#           0.0156565 ,  0.01494961],
#         [-0.0024165 ,  0.04842528, -0.02754558,  0.02155757,
#          -0.02986733, -0.01618611, -0.04429476,  0.0204294 ,
#          -0.03991799,  0.03240738],
#         [ 0.02901992, -0.00490061, -0.01441953, -0.03024347,
#           0.00707173,  0.01166882,  0.04656357, -0.04787156,
#          -0.03581198, -0.01590328],
#         [ 0.00111089, -0.02144997, -0.04005747, -0.0203434 ,
#           0.03359219,  0.04789321,  0.04347836,  0.03340851,
#          -0.02520965, -0.01633744],
#         [ 0.01992506,  0.04680424,  0.02446623,  0.01400879,
#          -0.04821155,  0.03000548, -0.01232864, -0.02590252,
#           0.0041991 , -0.0034299 ]],
#
#        [[ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [ 0.00761829,  0.04057116,  0.03163085,  0.00272648,
#           0.00885733,  0.02447461, -0.00452983, -0.04467104,
#          -0.04372801, -0.01260394],
#         [ 0.04895855, -0.04695929, -0.02911696,  0.02520982,
#          -0.02439896,  0.01605536, -0.03923155,  0.01901117,
#          -0.0134467 , -0.01331465],
#         [-0.03950752,  0.03749279,  0.03239187,  0.03665879,
#           0.04087729, -0.01088693,  0.01613141, -0.01390537,
#           0.02362523, -0.02000225],
#         [ 0.01653901, -0.0246666 ,  0.03465729,  0.02819493,
#           0.0063339 ,  0.0120704 ,  0.00223341,  0.00457009,
#           0.02366206,  0.0341008 ],
#         [ 0.01435934, -0.00184461, -0.02269125,  0.02443269,
#           0.01514728,  0.037056  ,  0.04290822,  0.01797519,
#          -0.04320264, -0.00057907]],
#
#        [[ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [ 0.04008509,  0.02832093,  0.04878101,  0.01572113,
#          -0.02982315, -0.04851944, -0.04369882,  0.02443994,
#           0.0059638 ,  0.04101935],
#         [-0.01034733, -0.02851223,  0.04348293,  0.0046258 ,
#           0.02197231, -0.01896415, -0.03995853, -0.04603981,
#          -0.04310041,  0.00517738],
#         [-0.02563368, -0.02574266,  0.01307834,  0.01339432,
#           0.03528993,  0.00916219, -0.00453103, -0.0164635 ,
#          -0.04621482, -0.04168385],
#         [ 0.047518  ,  0.01703514,  0.03374476, -0.0322057 ,
#          -0.03129524,  0.00828506, -0.04593601,  0.00448725,
#          -0.01353472, -0.03453135],
#         [ 0.00111089, -0.02144997, -0.04005747, -0.0203434 ,
#           0.03359219,  0.04789321,  0.04347836,  0.03340851,
#          -0.02520965, -0.01633744]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 8876, 3068, 9809, 4634], dtype=int32)

# %%
print(model.predict(embedded_docs)[0])
# Out:
# 1/1 [==============================] - 0s 11ms/step
# [[ 0.04008509  0.02832093  0.04878101  0.01572113 -0.02982315 -0.04851944
#   -0.04369882  0.02443994  0.0059638   0.04101935]
#  [ 0.04008509  0.02832093  0.04878101  0.01572113 -0.02982315 -0.04851944
#   -0.04369882  0.02443994  0.0059638   0.04101935]
#  [ 0.04008509  0.02832093  0.04878101  0.01572113 -0.02982315 -0.04851944
#   -0.04369882  0.02443994  0.0059638   0.04101935]
#  [ 0.04008509  0.02832093  0.04878101  0.01572113 -0.02982315 -0.04851944
#   -0.04369882  0.02443994  0.0059638   0.04101935]
#  [ 0.04895855 -0.04695929 -0.02911696  0.02520982 -0.02439896  0.01605536
#   -0.03923155  0.01901117 -0.0134467  -0.01331465]
#  [ 0.03579423 -0.01314446  0.01488168 -0.0026217   0.03737228  0.02327147
#    0.0026065  -0.01311885  0.03220752 -0.04723945]
#  [ 0.01653901 -0.0246666   0.03465729  0.02819493  0.0063339   0.0120704
#    0.00223341  0.00457009  0.02366206  0.0341008 ]
#  [-0.03756753 -0.04819441  0.00537108  0.0051433   0.02728419  0.02219539
#   -0.01196307 -0.0172388   0.01043321 -0.04930372]]

# %%
print(model.predict(embedded_docs)[0][0])
# Out:
# 1/1 [==============================] - 0s 13ms/step
# [ 0.04008509  0.02832093  0.04878101  0.01572113 -0.02982315 -0.04851944
#  -0.04369882  0.02443994  0.0059638   0.04101935]
